# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset of Diabetes .csv')
df
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
df = df.drop(columns=['ID'])
df
# Out:
#      No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  \
# 0        17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1        34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2        47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3        87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4        34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..         ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 995     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 996     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 997      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 998      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5
# 999      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
#     CLASS
# 0       N
# 1       N
# ...

# %%
df['Gender'] = df['Gender'].map({'M': 1, 'F': 0}).astype(bool)
df['CLASS'] = df['CLASS'].map({'Y': 0, 'Y ': 0,
                               'N': 1, 'N ': 1,
                               'P':2})
df
# Out:
#      No_Pation  Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  \
# 0        17975    True   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1        34221    True   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2        47975    True   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3        87656    True   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4        34223    True   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..         ...     ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 995     454317    True   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 996     876534    True   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 997      87654    True   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 998      24004    True   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5
# 999      24054    True   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
#      CLASS
# 0        1
# ...

# %%
df['CLASS'].value_counts()
# Out:
# CLASS
# Y     840
# N     102
# P      53
# Y       4
# N       1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No_Pation  1000 non-null   int64
#  1   Gender     1000 non-null   bool
#  2   AGE        1000 non-null   int64
#  3   Urea       1000 non-null   float64
#  4   Cr         1000 non-null   int64
#  5   HbA1c      1000 non-null   float64
#  6   Chol       1000 non-null   float64
#  7   TG         1000 non-null   float64
#  8   HDL        1000 non-null   float64
#  9   LDL        1000 non-null   float64
#  10  VLDL       1000 non-null   float64
#  11  BMI        1000 non-null   float64
#  12  CLASS      1000 non-null   int64
# dtypes: bool(1), float64(8), int64(4)
# memory usage: 94.9 KB

# %%
df.to_parquet('diabetes_dataset.parquet', index=False)

# %%
df2 = pd.read_parquet('diabetes_dataset.parquet', dtype_backend='numpy_nullable')
df2
# Out:
#      No_Pation  Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  \
# 0        17975    True   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1        34221    True   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2        47975    True   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3        87656    True   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4        34223    True   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..         ...     ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 995     454317    True   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 996     876534    True   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 997      87654    True   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 998      24004    True   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5
# 999      24054    True   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
#      CLASS
# 0        1
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No_Pation  1000 non-null   Int64
#  1   Gender     1000 non-null   boolean
#  2   AGE        1000 non-null   Int64
#  3   Urea       1000 non-null   Float64
#  4   Cr         1000 non-null   Int64
#  5   HbA1c      1000 non-null   Float64
#  6   Chol       1000 non-null   Float64
#  7   TG         1000 non-null   Float64
#  8   HDL        1000 non-null   Float64
#  9   LDL        1000 non-null   Float64
#  10  VLDL       1000 non-null   Float64
#  11  BMI        1000 non-null   Float64
#  12  CLASS      1000 non-null   Int64
# dtypes: Float64(8), Int64(4), boolean(1)
# memory usage: 107.6 KB

# %%
df.loc[df['CLASS'] == 2].describe()
# Out:
#            No_Pation        AGE       Urea          Cr      HbA1c       Chol  \
# count      53.000000  53.000000  53.000000   53.000000  53.000000  53.000000
# mean    64299.037736  43.283019   4.511321   66.075472   6.003774   4.579245
# std     95677.586440   7.761783   2.022438   41.566374   0.188069   1.042991
# min       252.000000  30.000000   2.100000   37.000000   5.700000   2.000000
# 25%     26665.000000  35.000000   3.400000   53.000000   5.900000   4.000000
# 50%     45384.000000  48.000000   4.400000   59.000000   6.000000   4.700000
# 75%     87660.000000  50.000000   5.000000   64.000000   6.100000   5.300000
# max    546543.000000  55.000000  17.100000  344.000000   6.400000   6.500000
#
#               TG        HDL        LDL       VLDL        BMI  CLASS
# count  53.000000  53.000000  53.000000  53.000000  53.000000   53.0
# mean    2.126415   1.127358   2.493396   0.983019  23.933962    2.0
# std     1.059236   0.383251   0.868633   0.501818   2.713991    0.0
# ...

# %%
#Standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dados_normalizados = pd.DataFrame(scaler.fit_transform(df.drop
(columns=['CLASS'])),
                                  columns=df.drop(columns=['CLASS']).columns)
dados_normalizados['CLASS'] = df['CLASS'].values
dados_normalizados
# Out:
#      No_Pation  Gender       AGE      Urea        Cr     HbA1c      Chol  \
# 0    -0.074747     0.0 -0.401144 -0.144781 -0.382672 -1.334983 -0.509436
# 1    -0.069940     0.0 -3.130017 -0.212954 -0.115804 -1.334983 -0.893730
# 2    -0.065869     0.0 -0.401144 -0.144781 -0.382672 -1.334983 -0.509436
# 3    -0.054126     0.0 -0.401144 -0.144781 -0.382672 -1.334983 -0.509436
# 4    -0.069939     0.0 -2.334096  0.673299 -0.382672 -1.334983  0.028576
# ..         ...     ...       ...       ...       ...       ...       ...
# 995   0.054384     0.0  1.986619  2.002680  0.467970 -0.505840  2.026906
# 996   0.179334     0.0 -2.561502 -0.724254 -0.149162  1.586758 -0.586295
# 997  -0.054127     0.0 -2.675205  0.673299  0.201102 -0.624289 -0.586295
# 998  -0.072963     0.0 -1.765581  0.230173 -0.165842 -0.624289  0.336011
# 999  -0.072948     0.0  0.053668 -0.042521 -0.032408 -0.545323 -0.816871
#
#            TG       HDL       LDL      VLDL       BMI  CLASS
# ...

# %%
dados_normalizados.describe()
# Out:
#           No_Pation  Gender           AGE          Urea            Cr  \
# count  1.000000e+03  1000.0  1.000000e+03  1.000000e+03  1.000000e+03
# mean  -1.065814e-17     0.0  1.705303e-16 -1.847411e-16  2.309264e-17
# std    1.000500e+00     0.0  1.000500e+00  1.000500e+00  1.000500e+00
# min   -8.003050e-02     0.0 -3.812235e+00 -1.576421e+00 -1.049842e+00
# 25%   -7.294548e-02     0.0 -2.874413e-01 -4.856476e-01 -3.493135e-01
# 50%   -6.988790e-02     0.0  1.673709e-01 -1.788675e-01 -1.491625e-01
# 75%   -6.663590e-02     0.0  6.221830e-01  1.960860e-01  6.766770e-02
# max    2.224434e+01     0.0  2.896244e+00  1.151286e+01  1.219348e+01
#
#              HbA1c          Chol            TG           HDL           LDL  \
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean      0.000000 -1.136868e-16 -1.136868e-16  5.151435e-17  1.278977e-16
# std       1.000500  1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(dados_normalizados.drop(columns=['CLASS']))
dados = pd.DataFrame(pca.transform(df.drop(columns=['CLASS'])),
                     columns=['PC1', 'PC2'])
dados['Classe'] = df['CLASS'].values
print(pca.explained_variance_ratio_)
# Out:
# [0.18165549 0.14777793]

# %%
dados
# Out:
#               PC1           PC2  Classe
# 0     -961.298951   -194.088373       1
# 1    -1880.602080   -386.132473       1
# 2    -2643.150880   -568.650641       1
# 3    -4867.736426  -1064.084154       1
# 4    -1880.521326   -395.142784       1
# ..            ...           ...     ...
# 995 -25399.190999  -5604.878668       0
# 996 -49087.253023 -10908.914581       0
# 997  -4866.503947  -1040.116864       0
# 998  -1290.634825   -262.805546       0
# 999  -1291.176850   -256.704771       0
#
# [1000 rows x 3 columns]

# %%
#plot 2d com a classe

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.scatterplot(data=dados, x='PC1', y='PC2', hue='Classe', palette='viridis')
plt.title('PCA - Diabetes Dataset')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(title='Classe')
plt.show()
